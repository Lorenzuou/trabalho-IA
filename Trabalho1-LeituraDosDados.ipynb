# %%
import pandas as pd

# %%
df = pd.read_csv('https://raw.githubusercontent.com/VitorBonella/PL-Dataset/main/dataset.csv',sep=";") #Leitura dos dados para o pandas
df.head(2)
# Out:
#     id                 data  sfh5711  sfh3400  tsl261r  sfh3410  sfh2430  \
# 0  355  2013-09-08 19:25:49     2568     1096     3932      914      855
# 1  356  2013-09-08 19:26:51     2651     1168     4095      993      923
#
#    bp104fas  tsl13s  tsl2569t_c  ...                      i6  \
# 0      2531    2406        6496  ...  -1,41733745231029e-006
# 1      2857    2446        6536  ...  -6,85966112547544e-011
#
#                       i7            probmax           energia  \
# 0  3,15336969940052e-009  0,890374128851521  3,17034178175013
# 1  3,90722879150443e-015  0,874335002692948  3,05605231787486
#
#            entropia          contraste     homogeneidade  \
# 0   6,5716176171224  -30,7129899022437  3,76304934586401
# 1  7,56143396285353  -37,1051952158663  3,72262223245045
#
#              correlacao                                       tipo_lampada  \
# 0   0,00030352446061056  metalica                                      ...
# 1  0,000268692571829909  metalica                                      ...
#
#   potencia
# 0      400
# 1      400
#
# [2 rows x 40 columns]

# %%
df.set_index('id',inplace=True) #Transformando a coluna id no indice da tabela

#Observem que a classe esta separada em duas colunas então devemos concatenadas para formar uma coluna só chamada classe
df['classe'] = df['tipo_lampada'].str.replace(" ", "") + df['potencia'].astype(str) 
df['classe']
# Out:
# id
# 355    metalica400
# 356    metalica400
# 357    metalica400
# 358    metalica400
# 359    metalica400
#           ...
# 656    metalica250
# 657    metalica250
# 658    metalica250
# 659    metalica250
# 660    metalica250
# Name: classe, Length: 297, dtype: object

# %%
df.head(5)
# Out:
#                     data  sfh5711  sfh3400  tsl261r  sfh3410  sfh2430  \
# id
# 355  2013-09-08 19:25:49     2568     1096     3932      914      855
# 356  2013-09-08 19:26:51     2651     1168     4095      993      923
# 357  2013-09-08 19:27:28     2500     1024     3867      825      766
# 358  2013-09-08 19:27:55     2240      462     3138      380      318
# 359  2013-09-08 19:28:40     2605     1201     4039      979      915
#
#      bp104fas  tsl13s  tsl2569t_c  tsl2569t_ir  ...                      i7  \
# id                                              ...
# 355      2531    2406        6496         6788  ...   3,15336969940052e-009
# 356      2857    2446        6536         7926  ...   3,90722879150443e-015
# 357      2456    2207        5912         6031  ...  -2,41752849217549e-015
# 358      1942    1725        3819         3759  ...   2,98121103828429e-013
# 359      2731    2505        7048         7095  ...   6,77157863228138e-008
#
#                probmax           energia          entropia          contraste  \
# id
# 355  0,890374128851521  3,17034178175013   6,5716176171224  -30,7129899022437
# 356  0,874335002692948  3,05605231787486  7,56143396285353  -37,1051952158663
# 357   0,88498796746712  3,13069373707728  6,85342760134283  -27,9068889939748
# 358    0,7646646581833  2,32154862004449  13,8784307675733  -109,018789473973
# 359  0,897764519281096  3,22179527617412  6,21806574418637  -54,8235378125258
#
#         homogeneidade            correlacao  \
# id
# 355  3,76304934586401   0,00030352446061056
# 356  3,72262223245045  0,000268692571829909
# 357  3,74882866962454  0,000232954297907698
# 358  3,42956382241494  0,000166201729869237
# 359  3,77587702004172  0,000259598389119525
#
#                                           tipo_lampada potencia       classe
# id
# 355  metalica                                      ...      400  metalica400
# 356  metalica                                      ...      400  metalica400
# 357  metalica                                      ...      400  metalica400
# 358  metalica                                      ...      400  metalica400
# 359  metalica                                      ...      400  metalica400
#
# [5 rows x 40 columns]

# %% [markdown]
# # Descrição do Dataset
#
# **De SFH5711 à TCS3414-C**: Sensores da placa (analógicos e digitais)
#
# **De DF01 à DF10**: Descritores de Fourier
#
# **De I1 à I7**: Descritores de HU
#
# **De probmax à correlação**: Descritores de Haralick

# %%
# Lista de Indices
FOURIER = ['df01', 'df02', 'df03', 'df04','df05', 'df06', 'df07', 'df08', 'df09', 'df10']
HU = ['i1', 'i2', 'i3', 'i4','i5', 'i6', 'i7']
HARALICK = ['probmax', 'energia', 'entropia', 'contraste','homogeneidade', 'correlacao']
ALL = FOURIER + HU + HARALICK

# %%
# Verificar o tipo da coluna
print(list(df[ALL].dtypes)) #o list(...) foi usado apenas para imprimir na vertical
df[ALL].head(2)
# Out:
# [dtype('O'), dtype('O'), dtype('O'), dtype('O'), dtype('O'), dtype('O'), dtype('O'), dtype('O'), dtype('O'), dtype('O'), dtype('O'), dtype('O'), dtype('O'), dtype('O'), dtype('O'), dtype('O'), dtype('O'), dtype('O'), dtype('O'), dtype('O'), dtype('O'), dtype('O'), dtype('O')]
#                    df01                df02                df03  \
# id
# 355  0,0879606602603602  0,0540590780493764  0,0252096142058536
# 356  0,0183325142757933  0,0641922380636373  0,0213351158490625
#
#                    df04                df05                 df06  \
# id
# 355  0,0274713661921584  0,0128341271697431  0,00837372424071006
# 356   0,028934652413586   0,012263060875406   0,0112299899510848
#
#                     df07                 df08                 df09  \
# id
# 355  0,00459165042660484  0,00516286747775679  0,00474694756923231
# 356  0,00356611493895844  0,00586153710536664  0,00374648636964241
#
#                     df10  ...                     i4                      i5  \
# id                        ...
# 355  0,00307480942393677  ...  5,71775104737315e-005   3,80815942436415e-009
# 356  0,00377850078446776  ...  1,01157608366481e-008  -5,39593107944031e-015
#
#                          i6                     i7            probmax  \
# id
# 355  -1,41733745231029e-006  3,15336969940052e-009  0,890374128851521
# 356  -6,85966112547544e-011  3,90722879150443e-015  0,874335002692948
#
#               energia          entropia          contraste     homogeneidade  \
# id
# 355  3,17034178175013   6,5716176171224  -30,7129899022437  3,76304934586401
# 356  3,05605231787486  7,56143396285353  -37,1051952158663  3,72262223245045
#
#                correlacao
# id
# 355   0,00030352446061056
# 356  0,000268692571829909
#
# [2 rows x 23 columns]

# %%
# salvando dado de trteino

# %%
'''
Os dados dos descritores como podemos observar na tabela acima estão com ","
porém o padrão para ponto flutuante (float) em python é "." logo a biblioteca 
entendeu que se tratavam de strings (objects para o pandas) e não de floats 
assim é importante transformar esses dados para float.
'''
df[ALL] = df[ALL].apply(lambda x: x.str.replace(',', '.').astype(float), axis=1)
print(list(df[ALL].dtypes))
df[ALL].head(2)
# Out:
# [dtype('float64'), dtype('float64'), dtype('float64'), dtype('float64'), dtype('float64'), dtype('float64'), dtype('float64'), dtype('float64'), dtype('float64'), dtype('float64'), dtype('float64'), dtype('float64'), dtype('float64'), dtype('float64'), dtype('float64'), dtype('float64'), dtype('float64'), dtype('float64'), dtype('float64'), dtype('float64'), dtype('float64'), dtype('float64'), dtype('float64')]
#          df01      df02      df03      df04      df05      df06      df07  \
# id
# 355  0.087961  0.054059  0.025210  0.027471  0.012834  0.008374  0.004592
# 356  0.018333  0.064192  0.021335  0.028935  0.012263  0.011230  0.003566
#
#          df08      df09      df10  ...            i4            i5  \
# id                                 ...
# 355  0.005163  0.004747  0.003075  ...  5.717751e-05  3.808159e-09
# 356  0.005862  0.003746  0.003779  ...  1.011576e-08 -5.395931e-15
#
#                i6            i7   probmax   energia  entropia  contraste  \
# id
# 355 -1.417337e-06  3.153370e-09  0.890374  3.170342  6.571618 -30.712990
# 356 -6.859661e-11  3.907229e-15  0.874335  3.056052  7.561434 -37.105195
#
#      homogeneidade  correlacao
# id
# 355       3.763049    0.000304
# 356       3.722622    0.000269
#
# [2 rows x 23 columns]

# %%
df_6 = df[FOURIER + HU]

# %%
X = df_6.values
y = df['classe'].values

# %%
# Salvando X e y em arquivos csv 
df_6.to_csv('X.csv',index=False)
df['classe'].to_csv('y.csv',index=False)

# %% [markdown]
# # Exemplos de utilização
#
# **Observação**: "pegar Z caracteristicas" significa que vamos pegar todos os dados (linhas) porém selecionando Z caracteristicas delas (colunas)

# %%
#Pegar todas caracteristicas
X = df[ALL]

X.head(3)
# Out:
#          df01      df02      df03      df04      df05      df06      df07  \
# id
# 355  0.087961  0.054059  0.025210  0.027471  0.012834  0.008374  0.004592
# 356  0.018333  0.064192  0.021335  0.028935  0.012263  0.011230  0.003566
# 357  0.018215  0.052010  0.019937  0.027750  0.009354  0.010829  0.003828
#
#          df08      df09      df10  ...            i4            i5  \
# id                                 ...
# 355  0.005163  0.004747  0.003075  ...  5.717751e-05  3.808159e-09
# 356  0.005862  0.003746  0.003779  ...  1.011576e-08 -5.395931e-15
# 357  0.006079  0.003583  0.002716  ...  5.386911e-09 -8.512721e-16
#
#                i6            i7   probmax   energia  entropia  contraste  \
# id
# 355 -1.417337e-06  3.153370e-09  0.890374  3.170342  6.571618 -30.712990
# 356 -6.859661e-11  3.907229e-15  0.874335  3.056052  7.561434 -37.105195
# 357  1.025674e-10 -2.417528e-15  0.884988  3.130694  6.853428 -27.906889
#
#      homogeneidade  correlacao
# id
# 355       3.763049    0.000304
# 356       3.722622    0.000269
# 357       3.748829    0.000233
#
# [3 rows x 23 columns]

# %%
#Pegar um unico conjunto de caracteristicas
X = df[HARALICK]

X.head(3)
# Out:
#       probmax   energia  entropia  contraste  homogeneidade  correlacao
# id
# 355  0.890374  3.170342  6.571618 -30.712990       3.763049    0.000304
# 356  0.874335  3.056052  7.561434 -37.105195       3.722622    0.000269
# 357  0.884988  3.130694  6.853428 -27.906889       3.748829    0.000233

# %%
#Pegar um par de caracteristicas
X = df[HARALICK + FOURIER]

X.head(3)
# Out:
#       probmax   energia  entropia  contraste  homogeneidade  correlacao  \
# id
# 355  0.890374  3.170342  6.571618 -30.712990       3.763049    0.000304
# 356  0.874335  3.056052  7.561434 -37.105195       3.722622    0.000269
# 357  0.884988  3.130694  6.853428 -27.906889       3.748829    0.000233
#
#          df01      df02      df03      df04      df05      df06      df07  \
# id
# 355  0.087961  0.054059  0.025210  0.027471  0.012834  0.008374  0.004592
# 356  0.018333  0.064192  0.021335  0.028935  0.012263  0.011230  0.003566
# 357  0.018215  0.052010  0.019937  0.027750  0.009354  0.010829  0.003828
#
#          df08      df09      df10
# id
# 355  0.005163  0.004747  0.003075
# 356  0.005862  0.003746  0.003779
# 357  0.006079  0.003583  0.002716

# %%
#Pegar os rotulos
y = df['classe']

y
# Out:
# id
# 355    metalica400
# 356    metalica400
# 357    metalica400
# 358    metalica400
# 359    metalica400
#           ...
# 656    metalica250
# 657    metalica250
# 658    metalica250
# 659    metalica250
# 660    metalica250
# Name: classe, Length: 297, dtype: object
